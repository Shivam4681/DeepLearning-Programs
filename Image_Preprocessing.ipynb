# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam4681/DeepLearning/blob/main/Image_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OpenCV (open Computer Vision) = use for read image data.

# %% [markdown]
# 1) Every colour image consist 3 Channel <br>
# 2) Range = 0-255

# %%
https://raw.githubusercontent.com/Shivam4681/DeepLearning/main/Datasets.txt/Alphabet%20Example.jpg

# %%
# Import Using Url
import cv2
import numpy as np
import requests


url1 = 'https://raw.githubusercontent.com/Shivam4681/DeepLearning/main/Datasets.txt/CuteCat.jpeg'

# Fetch the image
response = requests.get(url1)


# Display the image using matplotlib
plt.imshow(img)
plt.axis('off') # Hide axis
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# Using Upload Image in Colab
import cv2
path1 = "/content/CuteCat.jpeg"
img1 = cv2.imread(path1)
img1
# Out:
# array([[[122, 108,  90],
#         [121, 107,  89],
#         [121, 107,  89],
#         ...,
#         [251, 247, 188],
#         [251, 244, 187],
#         [252, 243, 186]],
#
#        [[122, 108,  90],
#         [121, 107,  89],
#         [121, 107,  89],
#         ...,
#         [250, 247, 186],
#         [252, 246, 187],
#         [253, 244, 187]],
#
#        [[121, 107,  89],
#         [121, 107,  89],
#         [122, 108,  90],
#         ...,
#         [250, 247, 186],
#         [253, 247, 188],
#         [255, 246, 189]],
#
#        ...,
#
#        [[151, 183, 232],
#         [151, 183, 232],
#         [151, 183, 232],
#         ...,
#         [160, 175, 208],
#         [159, 174, 207],
#         [159, 174, 207]],
#
#        [[151, 183, 232],
#         [151, 183, 232],
#         [152, 184, 233],
#         ...,
#         [159, 176, 209],
#         [158, 175, 208],
#         [158, 175, 208]],
#
#        [[152, 184, 233],
#         [153, 185, 234],
#         [153, 185, 234],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img1)

# %% [markdown]
# Convert BGR to RGB

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img2.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# Seperating Red, green and blue channels
